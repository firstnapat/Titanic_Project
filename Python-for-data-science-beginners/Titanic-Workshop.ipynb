# %%
# Import Library
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read CSV data

# %%
df = pd.read_csv('DataSet/titanic_Data.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Describe Data

# %%
df.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# PassengerId = ไอดีของผู้โดยสาร
# Survived = รอดหรือไม่ รอด 1 ไม่รอด 0
# Pclass = คลาสของผู้โดยสาร ระดับ 1 2 3
# Name = ชื่อ
# Sex = เพศ
# Age = อายุ
# SibSp ย่อมาจาก Sibling/Spousesมีพี่น้องหรือสามี/ภรรยาบนเรือหรือไม่ 1คน 2คน 3คน หรือ0ไม่มี
# Parch = Parent/Children มีพี่น้อง หรือลูกบนเรือหรือไม่ 1,2,3 มี 0 ไม่มี
# Ticket = เลขตั๋ว
# Fare = ราคาค่าโดยสาร
# Cabin = เลขห้องพักผู้โดยสาร
# Embarked = ลงเรือจากเมืองไหน S = Southamton, C = Cherbourg, Q = Queenstone

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
len(df)
# Out:
# 891

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Accesssing Data

# %% [markdown]
# Row

# %%
df.iloc[-10]
# Out:
# PassengerId                   882
# Survived                        0
# Pclass                          3
# Name           Markun, Mr. Johann
# Sex                          male
# Age                          33.0
# SibSp                           0
# Parch                           0
# Ticket                     349257
# Fare                       7.8958
# Cabin                         NaN
# Embarked                        S
# Name: 881, dtype: object

# %%
df.iloc[[-10]]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 881          882         0       3  Markun, Mr. Johann  male  33.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 881      0  349257  7.8958   NaN        S

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ### Accessing Data by Condition

# %%
df['Age'] == 35
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'] == 35]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 4              5         0       3
# 20            21         0       2
# 211          212         1       2
# 230          231         1       1
# 258          259         1       1
# 269          270         1       1
# 279          280         1       3
# 363          364         0       3
# 383          384         1       1
# 486          487         1       1
# 590          591         0       3
# 604          605         1       1
# 614          615         0       3
# 701          702         1       1
# 737          738         1       1
# 812          813         0       2
# 847          848         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# len(df[df['Age'] == 35])
(df[df['Age'] == 35]).shape
# Out:
# (18, 12)

# %%
df[df['Age'] < 35].shape
# Out:
# (479, 12)

# %%
df[df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# คำถาม : มีคนรอดกี่คน? คิดเป็นกี่เปอร์เซ็นต์?

# %%
df[df['Survived']==1].shape
# Out:
# (342, 12)

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# Hard Coding 
print("% if sur:" +str(342/891))
# Out:
# % if sur:0.3838383838383838

# %%
sur = df['Survived'].value_counts()[1]
psum = df['Survived'].value_counts().sum()
print(sur/psum)
# Out:
# 0.3838383838383838

# %%
# มีผู้ชายที่รอด 109 คน
df[df['Sex']=='male']['Survived'].value_counts()
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
# มีผู้ชายที่ในแต่ละคลาสกี่คน
df[df['Sex']=='male']['Pclass'].value_counts()
# Out:
# 3    347
# 1    122
# 2    108
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Excercise

# %% [markdown]
# คำถาม : หาสัดส่วนของผู้โดยสารแยกตามคลาส

# %%
cl1 = df['Pclass'].value_counts()[1]
cl2 = df['Pclass'].value_counts()[2]
cl3 = df['Pclass'].value_counts()[3]
csum = df['Pclass'].value_counts().sum()

# %%
print('% of class 1:'+str(cl1/csum))
print('% of class 2:'+str(cl2/csum))
print('% of class 3:'+str(cl3/csum))
# Out:
# % of class 1:0.24242424242424243
# % of class 2:0.20650953984287318
# % of class 3:0.5510662177328844

# %% [markdown]
# คำถาม : หาว่าผู้โดยสารชั้น 1 2 3 รอดชีวิตเป็นกี่เปอร์เซ็นต์ของผู้โดยสารชั้นนั้น ๆ ทั้งหมด

# %%
sur1 = df[df['Pclass']==1]['Survived'].value_counts()[1]
sur2 = df[df['Pclass']==2]['Survived'].value_counts()[1]
sur3 = df[df['Pclass']==3]['Survived'].value_counts()[1]

# %%
sursum1 = df[df['Pclass']==1]['Survived'].value_counts().sum()
sursum2 = df[df['Pclass']==2]['Survived'].value_counts().sum()
sursum3 = df[df['Pclass']==3]['Survived'].value_counts().sum()

# %%
print('% of sur class 1:'+str(sur1/sursum1))
print('% of sur class 2:'+str(sur2/sursum2))
print('% of sur class 3:'+str(sur3/sursum3))
# Out:
# % of sur class 1:0.6296296296296297
# % of sur class 2:0.47282608695652173
# % of sur class 3:0.24236252545824846

# %% [markdown]
# ### Add Delete row and columns

# %% [markdown]
# Add row

# %%
df_copy = df.copy()
df_copy.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_copy.loc[891] = [892,1,3,'AAA','male',20,0,0,'A00551B4',8,'C200','S']

# %%
df_copy.shape
# Out:
# (892, 12)

# %%
df_copy.loc[df_copy.shape[0]] = [892,1,3,'AAA','male',20,0,0,'A00551B4',8,'C200','S']

# %%
df_copy.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
# 891          892         1       3                                       AAA
# 892          892         1       3                                       AAA
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
# 891    male  20.0      0      0    A00551B4   8.00  C200        S
# 892    male  20.0      0      0    A00551B4   8.00  C200        S

# %% [markdown]
# Delete row

# %%
df_copy.drop(df_copy.iloc[[892]].index,inplace=True)

# %%
df_copy.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
# 891          892         1       3                                       AAA
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
# 891    male  20.0      0      0    A00551B4   8.00  C200        S

# %%
# ลบมากกว่า 1 row
df_copy.drop(df_copy.iloc[[890, 891]].index,inplace=True) # บอกมันว่าถ้าลบเสร็จแล้วให้เอาไปแทนใน df_copy เลยนะ
df_copy.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 885  female  39.0      0      5      382652  29.125   NaN        Q
# 886    male  27.0      0      0      211536  13.000   NaN        S
# 887  female  19.0      0      0      112053  30.000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0      111369  30.000  C148        C

# %%
df_copy.drop(df_copy.loc[[df_copy.shape[0]-1]].index,inplace=True) # ลบตัวสุดท้าย
df_copy.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# 887  female  19.0      0      0           112053  30.000   B42        S
# 888  female   NaN      1      2       W./C. 6607  23.450   NaN        S

# %%
# ลบคนอายุมากกว่า 30 
df_copy.drop(df_copy.loc[df_copy['Age']>30].index,inplace=True)
df_copy.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch            Ticket   Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.50   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.05   NaN        S
# 886    male  27.0      0      0            211536  13.00   NaN        S
# 887  female  19.0      0      0            112053  30.00   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.45   NaN        S

# %% [markdown]
# Add columns

# %%
df_copy['bahbah'] = pd.Series(np.random.randn(df_copy.shape[0]))
df_copy.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 5            6         0       3
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    bahbah
# 0      0         A/5 21171   7.2500   NaN        S -0.395596
# 2      0  STON/O2. 3101282   7.9250   NaN        S -0.566703
# 5      0            330877   8.4583   NaN        Q  0.573711
# 7      1            349909  21.0750   NaN        S -1.271146
# ...

# %% [markdown]
# Delete columns

# %%
del df_copy['bahbah']
df_copy.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 5            6         0       3
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S

# %% [markdown]
# ### Handling NA

# %% [markdown]
# Where is na?

# %%
df_drop = df.copy()
df_drop.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_drop[df_drop['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df_drop.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# drop NA

# %%
df_drop.dropna(inplace=True)

# %%
df_drop.shape
# Out:
# (183, 12)

# %% [markdown]
# drop NA in specific colum

# %%
df_drop = df.copy()

# %%
df_drop.dropna(subset=['Embarked'], inplace=True)
df_drop.shape
# Out:
# (889, 12)

# %% [markdown]
# ### Fill NA

# %% [markdown]
# 1. เติมด้วยค่าทางสถิติต่าง ๆ เช่น ค่าเฉลี่ย Mean Median Mode และอื่น ๆ
# 2. เติมด้วยการใช้ Machine Learning ทำนายค่า

# %%
df_copy = df.copy()
df_copy['Age'].isnull().sum()
# Out:
# 177

# %%
df_copy[df_copy['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# Mean

# %%
df_copy['Age'].hist() # ดูความหนาแน่นของค่าเฉลี่ยว่าอยู่แถวไหน
# Out:
# <AxesSubplot:>

# %%
mean = df_copy['Age'].mean()
mean
# Out:
# 29.69911764705882

# %%
df_copy['Age'].fillna(mean, inplace=True)

# %%
df_copy[df_copy['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df_copy['Age'].value_counts()
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: Age, Length: 89, dtype: int64

# %% [markdown]
# ปัญหาของ Mean และการใช้ Median
# 23 24 27 28** 29 29 30

# %%
df_copy = df.copy()
df_copy['Age'].isnull().sum()
# Out:
# 177

# %%
df_copy['Age'].hist()
median = df_copy['Age'].median()
median
# Out:
# 28.0

# %%
df_copy.loc[891] = [892,1,3,'AAA','male',90000,0,0,'A0051B7',8,'C200','S']

# %%
df_copy['Age'].mean()
# Out:
# 155.5317062937063

# %%
median = df_copy['Age'].median()
median
# Out:
# 28.0

# %%
df_copy['Age'].fillna(median, inplace=True)

# %%
df_copy[df_copy['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df_copy['Age'].value_counts() # มีคนอายุ 28 ตั้ง 202 คน เกิดจากข้อมูลเฉลี่ยเกินไม่หลากหลายพอ
# Out:
# 28.00       202
# 24.00        30
# 22.00        27
# 18.00        26
# 19.00        25
#            ...
# 36.50         1
# 55.50         1
# 0.92          1
# 23.50         1
# 90000.00      1
# Name: Age, Length: 89, dtype: int64

# %% [markdown]
# ### By Group

# %%
df_copy = df.copy()
df_copy[df_copy['Pclass']==1]['Age'].isnull().value_counts()
# Out:
# False    186
# True      30
# Name: Age, dtype: int64

# %%
mean1 = df_copy[df_copy['Pclass']==1]['Age'].mean()
mean1
# Out:
# 38.233440860215055

# %%
df_copy.loc[df_copy['Pclass']==1,'Age'] = df_copy[df_copy['Pclass']==1]['Age'].fillna(mean1)

# %%
df_copy['Age'].value_counts()
# Out:
# 38.233441    30
# 24.000000    30
# 22.000000    27
# 18.000000    26
# 19.000000    25
#              ..
# 36.500000     1
# 55.500000     1
# 0.920000      1
# 23.500000     1
# 74.000000     1
# Name: Age, Length: 89, dtype: int64

# %%
df_copy[df_copy['Pclass']==1]['Age'].isnull().value_counts()
# Out:
# False    216
# Name: Age, dtype: int64

# %%
df_copy[df_copy['Pclass']==3]['Age'].isnull().value_counts()
# Out:
# False    355
# True     136
# Name: Age, dtype: int64

# %% [markdown]
# ลองเติม na ด้วย ค่าเฉลี่ยของชาย และหญิง

# %%
# ก่อนอื่นลองดูค่าเฉลี่ยผู้หญิงที่อยู่คลาสสาม
df_copy[(df_copy['Pclass']==3) & (df_copy['Sex']=='female')]['Age'].mean()
# Out:
# 21.75

# %%
df_copy[df_copy['Pclass']==3]['Age'].mean()
# Out:
# 25.14061971830986

# %% [markdown]
# ### Exercise

# %% [markdown]
# เติม na อายุของผู้หญิงคลาส 3 ด้วยค่ากลาง(Median)

# %% [markdown]
# เติม na อายุของผู้ชายคลาส 3 ด้วยค่าเฉลี่ย(Mean)

# %%
median_fc3 = df_copy[(df_copy['Pclass']==3) & (df_copy['Sex']=='female')]['Age'].median()
median_fc3
# Out:
# 21.5

# %%
# เติม na ของผู้หญิงคลาส3
df_copy.loc[(df_copy['Pclass']==3) & (df_copy['Sex']=='female'),'Age'] = df_copy[(df_copy['Pclass']==3) & 
                                                                                 (df_copy['Sex']=='female')]['Age'].fillna(median_fc3)

# %%
df_copy[(df_copy['Pclass']==3) & (df_copy['Sex']=='female')]['Age'].value_counts()
# Out:
# 21.50    42
# 18.00     8
# 22.00     6
# 24.00     4
# 31.00     4
# 9.00      4
# 2.00      4
# 21.00     4
# 30.00     3
# 29.00     3
# 5.00      3
# 45.00     3
# 27.00     3
# 26.00     3
# 16.00     3
# 15.00     3
# 4.00      3
# 23.00     2
# 39.00     2
# 0.75      2
# 25.00     2
# 14.00     2
# 1.00      2
# 41.00     2
# 19.00     2
# 20.00     2
# 28.00     2
# 17.00     2
# 8.00      1
# 11.00     1
# 13.00     1
# 30.50     1
# 48.00     1
# 43.00     1
# 32.00     1
# 36.00     1
# 63.00     1
# 37.00     1
# 38.00     1
# 14.50     1
# 10.00     1
# 3.00      1
# 35.00     1
# 33.00     1
# 47.00     1
# 40.00     1
# 6.00      1
# Name: Age, dtype: int64

# %%
mean_mc3 = df_copy[(df_copy['Pclass']==3) & (df_copy['Sex']=='male')]['Age'].mean()
mean_mc3
# Out:
# 26.507588932806325

# %%
# เติม na ของผู้ชายคลาส3
df_copy.loc[(df_copy['Pclass']==3) & (df_copy['Sex']=='male'),'Age'] = df_copy[(df_copy['Pclass']==3) & 
                                                                                 (df_copy['Sex']=='male')]['Age'].fillna(mean_mc3)

# %%
df_copy[(df_copy['Pclass']==3) & (df_copy['Sex']=='male')]['Age'].value_counts()
# Out:
# 26.507589    94
# 22.000000    14
# 20.000000    13
# 21.000000    13
# 19.000000    12
#              ..
# 59.000000     1
# 37.000000     1
# 70.500000     1
# 12.000000     1
# 74.000000     1
# Name: Age, Length: 64, dtype: int64

# %%
df_copy[(df_copy['Pclass']==3) & (df_copy['Sex']=='male')]['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Convert String Feature to numerical

# %%
df_pre = df.copy()
df_pre.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_pre.loc[(df_pre['Sex']=='male'), 'Sex_num'] = 1
df_pre.loc[(df_pre['Sex']=='female'), 'Sex_num'] = 0

# %%
df_pre.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_num
# 0      0         A/5 21171   7.2500   NaN        S      1.0
# 1      0          PC 17599  71.2833   C85        C      0.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0.0
# 3      0            113803  53.1000  C123        S      0.0
# ...

# %% [markdown]
# ### Excercise

# %% [markdown]
# ให้แปลง Columns สถานที่ลงเรือ embarked เป็น S=0 C=1 และ Q=2 ลงใน Columns ใหม่ ชื่อ Embarked_num ลงในตัวแปร df_pre

# %%
df_pre = df.copy()
df_pre.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_pre.loc[(df_pre['Embarked']=='S'), 'Embarked_num'] = 0
df_pre.loc[(df_pre['Embarked']=='C'), 'Embarked_num'] = 1
df_pre.loc[(df_pre['Embarked']=='Q'), 'Embarked_num'] = 2

# %%
df_pre.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  \
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
#
#      Embarked_num
# 886           0.0
# 887           0.0
# 888           0.0
# 889           1.0
# ...

# %% [markdown]
# ### Visulaization and Correlation

# %% [markdown]
# Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df_pre['Age'].dropna(),bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
mean1 = df_pre[df_copy['Pclass']==1]['Age'].mean()
df_pre.loc[df_pre['Pclass']==1,'Age'] = df_pre[df_pre['Pclass']==1]['Age'].fillna(mean1)

mean2 = df_pre[df_copy['Pclass']==2]['Age'].mean()
df_pre.loc[df_pre['Pclass']==2,'Age'] = df_pre[df_pre['Pclass']==2]['Age'].fillna(mean2)

mean3 = df_pre[df_copy['Pclass']==3]['Age'].mean()
df_pre.loc[df_pre['Pclass']==3,'Age'] = df_pre[df_pre['Pclass']==3]['Age'].fillna(mean3)
df_pre['Age'].isnull().value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %%
plt.hist(df_pre['Age'],bins=5)
# Out:
# (array([100., 493., 218.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
import seaborn as sns

# %%
sns.histplot(df_pre['Age'],bins=10,)
plt.grid()

# %%
sns.set_context(rc={'figure.figsize':{15,10}})

# %%
sns.histplot(df_pre['Age'],bins=10,color='red')
plt.grid()

# %% [markdown]
# Boxplot

# %%
sns.boxplot(x=df_pre['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x=df_pre['Sex'],y=df_pre['Age'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df_pre['Pclass'],y=df_pre['Age'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# Violinplot

# %%
sns.violinplot(x=df_pre['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.violinplot(x=df['Age'].dropna()) # เอา na ออก
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.violinplot(df_pre[df_pre['Pclass']==2]['Age'],df_pre['Sex'])
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# KDE = kernal density estimation

# %%
sns.kdeplot(df_pre['Age']) # kde เอาไว้ประมาณค่า cumulative
# รูปร่างเหมือน เส้น estimate ของ histogram
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(df_pre['Age'], cumulative=True) # ค่า cumulative of  prob ของอายุ 0-20 มีค่าป็น 20% ของข้อมูลทั้งหมด
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# หาค่าความสัมพันธ์แปรผันตามกันของข้อมูล ด้วยฟังก์ชัน
# pairplot and correlation

# %%
sns.pairplot(df_pre)

# %%
df_pre.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin           687
# Embarked          2
# Embarked_num      2
# dtype: int64

# %%
del df_pre['Cabin']

# %%
df_pre.dropna(inplace=True)
df_pre.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# Embarked_num    0
# dtype: int64

# %%
sns.pairplot(df_pre)

# %%
# เพิ่มเส้ Regression เพื่อดูความสัมพันธ์
sns.pairplot(df_pre, kind='reg')

# %%
# ทำให้ผู้ชายผู้หญิงเป็น 1, 0
df_pre.loc[(df_pre['Sex']=='male'), 'Sex_num'] = 1
df_pre.loc[(df_pre['Sex']=='female'), 'Sex_num'] = 0

# %%
sns.jointplot(x="Sex_num", y="Survived", data=df_pre, kind="reg")

# %% [markdown]
# factorplot

# %%
sns.factorplot(x='Sex_num',data=df_pre)
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='Sex_num',data=df_pre,kind='violin')
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='Pclass',y='Survived',data=df_pre,kind='violin')
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='Pclass',y='Fare',hue='Survived',data=df_pre,kind='violin',size=8,color='red')
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot(x='Pclass',y='Fare',hue='Sex_num',col='Survived',data=df_pre,kind='violin',size=8,color='red')
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Exercise
# ผู้โดยสารแต่ละคลาส จากแต่ละเมือง จ่ายค่าตั๋วมาเท่าไหร่บ้าง แยกตามประเภทชายหญิง

# %% [markdown]
# กำหนดให้ใช้ factorplot และ x เท่ากับ ผู้โดยสารแต่ละคลาส ทั้งแบบ violin และ Bar เพื่อสังเกตความแตกต่าง

# %%
sns.factorplot(x='Pclass',y='Fare',hue='Embarked_num',col='Sex',data=df_pre,kind='violin',size=8)
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot(x='Pclass',y='Fare',hue='Embarked_num',col='Sex',data=df_pre,kind='bar',size=8,color='red')
# Out:
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\acer\miniconda3\envs\tfpt\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df_pre.loc[(df_pre['Embarked']=='Q')&(df_pre['Pclass']==1)]
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 245          246         0       1  Minahan, Dr. William Edward    male  44.0
# 412          413         1       1       Minahan, Miss. Daisy E  female  33.0
#
#      SibSp  Parch Ticket  Fare Embarked  Embarked_num  Sex_num
# 245      2      0  19928  90.0        Q           2.0      1.0
# 412      1      0  19928  90.0        Q           2.0      0.0

# %%
df_pre.loc[(df_pre['Embarked']=='Q')&(df_pre['Pclass']==2)]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 303          304         1       2             Keane, Miss. Nora A  female
# 322          323         1       2       Slayter, Miss. Hilda Mary  female
# 626          627         0       2  Kirkland, Rev. Charles Leonard    male
#
#           Age  SibSp  Parch  Ticket   Fare Embarked  Embarked_num  Sex_num
# 303  29.87763      0      0  226593  12.35        Q           2.0      0.0
# 322  30.00000      0      0  234818  12.35        Q           2.0      0.0
# 626  57.00000      0      0  219533  12.35        Q           2.0      1.0
